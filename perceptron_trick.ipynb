# %%
from sklearn.datasets import make_classification
import numpy as np
x,y=make_classification(n_samples=100,n_features=2,n_informative=1,n_clusters_per_class=1,n_redundant=0,n_classes=2,hypercube=False,class_sep=10,random_state=41)

# %%
import matplotlib.pyplot as plt
plt.scatter(x[:,0],x[:,1],c=y,cmap='winter')

# %%
def step(x):
    return 1 if x>0 else 0

# %%
def perceptron(x,y):
    x=np.insert(x,0,1,axis=1)
    weight=np.ones(x.shape[1])
    lr=0.1
    for i in range(100):
        j=np.random.randint(1,100)
        j_hat=step(np.dot(x[j],weight))
        weight+=lr*(y[j]-j_hat)*x[j]
    return weight[0],weight[1:]

# %%
intercept_,coef_=perceptron(x,y)

# %%
m=-(coef_[0]/coef_[1])
b=-(intercept_/coef_[1])

# %%
x_input=np.linspace(-3,3,100)
y_input=m*x_input+b
y_input
# Out:
# array([ 18.89983524,  18.37748388,  17.85513252,  17.33278115,
#         16.81042979,  16.28807843,  15.76572707,  15.24337571,
#         14.72102435,  14.19867299,  13.67632163,  13.15397027,
#         12.63161891,  12.10926754,  11.58691618,  11.06456482,
#         10.54221346,  10.0198621 ,   9.49751074,   8.97515938,
#          8.45280802,   7.93045666,   7.4081053 ,   6.88575394,
#          6.36340257,   5.84105121,   5.31869985,   4.79634849,
#          4.27399713,   3.75164577,   3.22929441,   2.70694305,
#          2.18459169,   1.66224033,   1.13988897,   0.6175376 ,
#          0.09518624,  -0.42716512,  -0.94951648,  -1.47186784,
#         -1.9942192 ,  -2.51657056,  -3.03892192,  -3.56127328,
#         -4.08362464,  -4.60597601,  -5.12832737,  -5.65067873,
#         -6.17303009,  -6.69538145,  -7.21773281,  -7.74008417,
#         -8.26243553,  -8.78478689,  -9.30713825,  -9.82948961,
#        -10.35184098, -10.87419234, -11.3965437 , -11.91889506,
# ...

# %%
plt.scatter(x[:,0],x[:,1],c=y,cmap='winter',s=100)
plt.plot(x_input,y_input,color='red',linewidth=3)
plt.ylim(-5,5)
# Out:
# (-5.0, 5.0)
